# %% [markdown]
# # LES BASES DE PYTHON

# %% [markdown]
# ## Des boucles et des fonctions

# %%
#les fonctions principales de turtle
from turtle import forward, backward, left, right, done, down, up, speed

# %% [markdown]
# ### Motifs colorés

# %% [markdown]
# Dans cet exercice, nous allons réutiliser le motif dessiné par la fonction motif(x) que vous avez réalisée dans votre dernier notebook. Donc vous devrez l’importer depuis la bibliothèque ‘motifColore.py’. Pour cela, il faut :
# - ouvrir le fichier motifColore.py dans ce notebook et cliquez sur installer le module
# - importez la fonction motif du module motifColore dans la cellule ci-dessous

# %% [markdown]
# Dans la suite de ce notebook, tous les motifs devront faire 20 pixels de coté.
#
# Ecrivez un programme qui demande à l’utilisateur combien de motifs il souhaite dessiner, puis les dessine, tous alignés :![m1.JPG](attachment:m1.JPG)

# %% [markdown]
# Ecrivez un programme qui dessine un damier de motifs après avoir demandé combien l’utilisateur en souhaite en largeur et en hauteur :
# Indiquez le nombre de motifs en largeur : **5**
# Indiquez le nombre de motifs en hauteur : **8**
# ![m2.JPG](attachment:m2.JPG)

# %%
speed("fastest")

nbMotifX=int(input("Indiquez le nombre de motifs en largeur : "))
nbMotifY=int(input("Indiquez le nombre de motifs en hauteur : "))

#répondre ici

done()

# %% [markdown]
# Ecrire un script qui demande un nombre et affiche sa table en utilisant la fonction précédente.

# %% [markdown]
# Ecrivez un programme qui dessine un cercle complet de motifs en fonction du nombre de motif demandé :
# Indiquez le nombre de motif : **31**
#
# ![m3.JPG](attachment:m3.JPG)

# %%
speed("fastest")
nbMotif=int(input("Indiquez le nombre de motifs : "))

#répondre ici

done()

# %% [markdown]
# ### Des fonctions et des boucles avec turtle

# %% [markdown]
# #### des escaliers ...

# %% [markdown]
# écrivez deux fonctions **marcheHaut()** et **marcheBas()** qui dessinent respectivement les deux figures ci-dessous. La hauteur et la longueur de la marche font 20 pixels : ![e1.JPG](attachment:e1.JPG)

# %%
#répondre ici

marcheHaut()
marcheBas()
done()

# %% [markdown]
# Ecrivez deux fonctions **escalierMontant(nbMarche)** et **escalierDescendant(nbMarche)** qui réalisent respectivement les deux figures ci-dessous pour nbMarche = 5 : ![e2.JPG](attachment:e2.JPG)

# %%
#répondre ici

escalierMontant(5)
escalierDescendant(5)
done()

# %% [markdown]
# En utilisant les fonctions écrites précédemment, réalisez la figure suivante : ![e3.JPG](attachment:e3.JPG)

# %%
up()
backward(300)
down()

#répondre ici

done()

# %% [markdown]
# Idem avec la figure ci-dessous. Il y a 6 escaliers, le premier a 1 marches, les suivants ont une marche de plus que le précédent : ![e4.JPG](attachment:e4.JPG)

# %%
up()
backward(310)
down()

#répondre ici


done()

# %% [markdown]
# Puis avec celle-ci. Il y a 6 escaliers, le premier a 6 marches, les suivants ont une marche de moins que le précédent : ![e5.JPG](attachment:e5.JPG)

# %%
up()
backward(310)
down()

#répondre ici


done()

# %% [markdown]
# ### Ciel étoilé

# %% [markdown]
# Vous aurez besoin ici de quelques fonctions turtle supplémentaires.

# %%
from turtle import bgcolor, goto, fillcolor, begin_fill, end_fill, pencolor
#les dimensions de la fenetre de dessin turtle sont
largeurFenetre = 315*2
hauteurFenetre = 240*2

# %% [markdown]
# écrivez une fonction **etoile(long)** qui trace avec Turtle, une étoile composée de cinq segments de longueur **long**, remplie en blanc, avec les traits blancs. La fonction termine en levant le crayon.
# ***Aide :*** la somme des angles des cinq branches de l’étoile vaut 180° ![e6.JPG](attachment:e6.JPG)

# %%
#répondre ici

# %% [markdown]
# Testez ci-dessous sur un fond noir :

# %%
bgcolor('black')
etoile(200)
done()

# %% [markdown]
# Ecrivez une fonction **etoileAlea(x,y)** qui utilise la fonction etoile(long). Elle place une étoile au point de coordonnées (x, y) dont l’orientation et la taille sont aléatoires. La taille variera entre 10 et 50 pixels. Exemple :![e7.JPG](attachment:e7.JPG)
# ***Aide :*** Pour obtenir un nombre aléatoire compris entre i et j, vous pouvez utiliser la fonction randint(i, j) qui se trouve dans le module random.

# %%
from random import randint

#répondre ici

# %% [markdown]
# Testez ci-dessous sur un fond noir :

# %%
bgcolor('black')
etoileAlea(0, 0)
etoileAlea(100, 0)
etoileAlea(0, 100)
etoileAlea(100, 100)
done()

# %% [markdown]
# Ecrivez le programme permettant de répartir aléatoirement sur l’ensemble de la fenêtre graphique une centaine de ces petites étoiles sur un fond bleu :

# %%
#répondre ici
