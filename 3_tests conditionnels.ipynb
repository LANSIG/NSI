# %% [markdown]
# # LES BASES DE PYTHON

# %% [markdown]
# ## Les tests et les structures de contrôle.

# %% [markdown]
# ### Tests simples

# %% [markdown]
# Complétez le programme suivant pour qu’il corresponde à l'agorithme suivants :
# - demander de saisir son année de naissance
# - si annee = 2000 afficher 'Vous êtes un bébé de l'an 2000'

# %%
annee = int(input('Saisir votre année de naissance : '))

# %% [markdown]
# Complétez le programme suivant pour qu’il corresponde à l'agorithme suivants :
# - demander de saisir son année de naissance
# - si annee > 2000 afficher 'Vous êtes né au XXIeme siècle'
# - sinon afficher 'Vous êtes né au XXeme siècle'

# %%
annee = int(input('Saisir votre année de naissance : '))

# %%
annee = int(input('Saisir votre année de naissance : '))

# %% [markdown]
# Complétez le programme suivant pour qu’il corresponde à l'agorithme suivants :
# - demander de saisir son année de naissance
# - si annee > 2000 afficher 'Vous êtes né au XXIeme siècle'
# - sinon si annee > 1900 afficher 'Vous êtes né au XXeme siècle'
# - sinon afficher 'Vous êtes mort depuis longtemps !'

# %%
annee = int(input('Saisir votre année de naissance : '))

# %% [markdown]
# Réécrivez le programme précédent, avec le même fonctionnement, en utilisant uniquement des tests **<**.

# %% [markdown]
# Expliquez, **avant d'exécuter la cellule**, ce que fait ce programme :

# %%
a, b = int(input('Saisir un nombre : ')), int(input('Saisir un autre nombre : '))
if a > b :
    m = a
else :
    m = b
print('Le plus grand est ',m)

# %% [markdown]
# En s’appuyant sur les modèles précédents, réaliser un programme qui affiche la plus grande valeur parmi trois variables entières a,b et c (trois questions successives pour entrer les 3 nombres).

# %% [markdown]
# Proposez un script qui demande de rentrer un nombre et qui indique si celui-ci est pair ou impair.![3.JPG](attachment:3.JPG)

# %% [markdown]
# Proposez un programme qui demande deux nombres et qui indique si l’un est le carré de l’autre ou pas. ![4.JPG](attachment:4.JPG)

# %% [markdown]
# Proposez un script qui demande les nom et prénom de l’utilisateur. Le programme reconnait les « Dupont » et leur adresse un message personnalisé. Ce nom doit être détecté quel que soit la casse. ![5.JPG](attachment:5.JPG)

# %%
name=input("Comment vous appelez-vous ?  ")

# %% [markdown]
# ### Moyenne

# %% [markdown]
# Ecrivez un programme qui demande successivement trois notes /20 et affiche la moyenne si les trois notes sont valides (comprises entre 0 et 20). Dans le cas contraire (une ou plusieurs notes non valides), on affiche le message « Calcul impossible ».

# %% [markdown]
# Améliorez le programme (copier le ci-dessous) en ajoutant une appréciation :
# - Moyenne inférieure à 9.5 : « A améliorer »
# - Moyenne comprise entre 9.5 et 11 : « Passable »
# - Moyenne supérieure à 11 et inférieure à 14 : « Satisfaisant »
# - Moyenne supérieure à 14 : « Très bien »

# %% [markdown]
# ### Triangle

# %% [markdown]
# On donne un rappel des différents types de triangle : ![6.JPG](attachment:6.JPG)

# %% [markdown]
# Proposez un programme qui demande successivement les trois angles d’un supposé triangle et qui indique s’il s’agit bien d’un triangle.![7.JPG](attachment:7.JPG)

# %%
a=float(input("Donnez le 1er angle de votre triangle   "))
b=float(input("Donnez le 2eme angle de votre triangle  "))
c=float(input("Donnez le 3eme angle de votre triangle  "))

# %% [markdown]
# Améliorez votre programme en indiquant en plus si le triangle est isocèle.

# %% [markdown]
# Améliorez votre programme en indiquant en plus si le triangle est équilatéral.

# %% [markdown]
# Améliorez votre programme en indiquant en plus si le triangle est rectangle, isocèle rectangle ou plat.

# %% [markdown]
# ### Année bissextile

# %% [markdown]
# Ecrivez un programme Python qui demande de saisir une année et indique si l’année correspondante est bissextile en affichant : "Cette année est bissextile" ou "Cette année n’est pas bissextile" selon le cas.
#
# **Info :** Les années bissextiles sont celles qui sont divisibles par 4, sauf lorsqu’elles débutent un siècle non multiple de 400. (Par exemple : l’année 2000 était bissextile : 2000 débute un siècle mais 2000/400 = 50 ; l’année 2100 ne sera pas bissextile).

# %%
a=int(input("Saisir une année pour savoir si elle est bissextile :"))
