# %% [markdown]
# # Un premier notebook Jupyter #

# %% [markdown]
# ### Les cellules de texte
#
# Voici quelques exemples de syntaxe markdown simple. Double cliquez sur la cellule pour modifier le texte puis cliquez sur run pour visualiser le résultat.

# %% [markdown]
# Ceci est une cellule de texte.
# Un saut de ligne : pas de passage à la ligne !
#
# Une ligne vierge pour passer a la ligne

# %% [markdown]
# #  Titre 1
# ## Titre 2
# ###  Titre 3
# #### Titre 4

# %% [markdown]
# *Texte en italique*<br/>
# **Texte en gras**<br/>
# ***Texte en italique et en gras***<br/>
# ~~Ce texte est barré.~~ mais pas celui-là.

# %% [markdown]
# Une liste non numérotée
# - Liste 1
# - Liste 2
# - Liste 3
#
# Une liste numérotée
# 1. Liste 1
# 2. Liste 2
# 3. Liste 3

# %% [markdown]
# ## Les cellules de code

# %%
#ceci est est une cellule de code
#on peut mettre du texte en commentaire en utilisant le #
a = 5
b = 6
print(a+b)

# %%
#afficher dans la console une variable mémorisée
print(a)

# %%
#ici, on va générer une sortie réutilisable : attention, une seule par cellule
a

# %%
#réutilisation d'une sortie
print(Out[4] + 4)

# %% [markdown]
# ## Un premier programme

# %% [markdown]
# Ecrire ici un programme qui demande son nom à l'utilisateur du programme et affiche le message (personnalisé avec le prénom saisi).
#
# 'Bonjour Marc !!'

# %%
a = input('Donnez votre prénom ')
print('Bonjour', a, '!!')
