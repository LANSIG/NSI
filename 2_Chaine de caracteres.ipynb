# %% [markdown]
# # LES BASES DE PYTHON

# %% [markdown]
# ## Les chaînes de caractères

# %% [markdown]
# ### Construction d’une chaîne de caractères

# %% [markdown]
# Proposez un script qui produit une variable C contenant la chaine ‘Hello World !!’ à partir des variables A et B. Affichez le contenu de C.

# %%
A = 'Hello'
B = 'World'

# %% [markdown]
# Créez une variable ch qui contient le mot « cucurlucucu » en utilisant au maximum la variable A.Affichez le contenu de ch.

# %%
A = 'cu'

# %% [markdown]
# ### Dialogue avec un utilisateur du programme

# %% [markdown]
# Proposez un script qui demande un mot à l’utilisateur, le stocke dans une variable et affiche ce mot.

# %% [markdown]
# Proposez un script qui demande un mot à l’utilisateur, le stocke dans une variable et affiche ce mot 5 fois de suite en sautant à la ligne. Comme ci-dessous : ![1.png](attachment:1.png)

# %%
#aide : Le caractère qui permet de passer à la ligne est '\n'.

# %% [markdown]
# Ecrivez un programme qui permet d’afficher le dialogue suivant : (les réponses sont en gras). Evidemment ce programme doit fonctionner même si vous ne vous appelez pas Marc …
#
# Bonjour !
# Quel est ton prénom ?	**Marc**
# Bienvenue Marc, nous allons faire une addition.
# Entre un nombre :	**8**
# Entre un autre nombre :		**5**
# La somme de 8 et 5 est égale à 13 !

# %% [markdown]
# Pour le programme précédent, entrez un nombre à virgule à la question « Entre un nombre ». Expliquez ce qui se passe (s’il il se passe quelque chose). Dans le cas où votre programme renverrait une exception, expliquez pourquoi. Proposez une modification  pour autoriser ce fonctionnement.

# %% [markdown]
# **Réponse :**

# %% [markdown]
# Ecrivez un programme qui permet d’afficher le dialogue suivant : (les réponses sont en gras).
#
# Quel est ton prénom ?	**Jean**
# Quel est ton nom ?	**Dupont**
# Tes initiales sont JD

# %% [markdown]
# Proposez un script qui demande un mot à l’utilisateur, puis demande un nombre, puis affiche le mot autant de fois que le nombre saisi en sautant à la ligne comme ci-dessous :![2.png](attachment:2.png)

# %% [markdown]
# ### Minuscule et majuscule

# %% [markdown]
# Les méthodes **upper()**, **lower()** et **capitalize()** permettent respectivement de convertir une chaine en majuscule, minuscule, ou juste la première lettre en majuscule.

# %% [markdown]
# Proposez un script qui demande successivement son nom et son prénom a l’utilisateur et lui retourne un message type « Bonjour Jean DUPONT » en respectant cette casse quelque soit la façon dont les nom et prénom ont été tapé.![3.png](attachment:3.png)
